# %% [markdown]
# <a href="https://colab.research.google.com/github/vansh-virmani/NextGenAI/blob/main/Intent_Classfication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries: text processing
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

#Second Import sklearn depencdencies:
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
training_data=[
    ("hello","greet"),("hi there","greet"),("good morning","greet",
                                            ),("hey","greet"),
    ("what's the weather today","weather"),
     ("tell me weather","weather"),(
         "is it raining","weather"),

    ("open","open_app"),
     ("open google"," open_app"),
      ("open youtube","open_app"),("bye","exit"),
       ("goodbye","exit")

]

# %%
sentences=[]
labels=[]
for text,intent in training_data:
  sentences.append(text)
  labels.append(intent)

# %%
import string
punc = string.punctuation

# For tokenization


def preprocess_text(sentences):
    cleaned_sentences = []
    # Logic for text processing
    # Step-1: Lowercase
    for sentence in sentences:
        text = sentence.lower()
        print("After Lowercase :",text)

        tokens = word_tokenize(text)
        print("Tokens :",tokens)

        punctuation_filter = [word for word in tokens if word not in punc]
        print("Removed Punctuations:",punctuation_filter)

        eng_stopwords = stopwords.words("english")
        filtered_tokens = [word for word in punctuation_filter if word not in eng_stopwords]
        print("Removed stopwords:",filtered_tokens)

        wnet = WordNetLemmatizer()
        lemmatized_words = []
        for word in filtered_tokens:
            lemmatized_words.append(wnet.lemmatize(word,"v"))

        print("Lemmatization:",lemmatized_words)
        cleaned_text = " ".join(lemmatized_words)
        cleaned_sentences.append(cleaned_text)

        print("="*50)

    return cleaned_sentences

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
clean_data=preprocess_text(sentences)
# Out:
# After Lowercase : hello
# Tokens : ['hello']
# Removed Punctuations: ['hello']
# Removed stopwords: ['hello']
# Lemmatization: ['hello']
# ==================================================
# After Lowercase : hi there
# Tokens : ['hi', 'there']
# Removed Punctuations: ['hi', 'there']
# Removed stopwords: ['hi']
# Lemmatization: ['hi']
# ==================================================
# After Lowercase : good morning
# Tokens : ['good', 'morning']
# Removed Punctuations: ['good', 'morning']
# Removed stopwords: ['good', 'morning']
# Lemmatization: ['good', 'morning']
# ==================================================
# After Lowercase : hey
# Tokens : ['hey']
# Removed Punctuations: ['hey']
# Removed stopwords: ['hey']
# Lemmatization: ['hey']
# ==================================================
# After Lowercase : what's the weather today
# Tokens : ['what', "'s", 'the', 'weather', 'today']
# Removed Punctuations: ['what', "'s", 'the', 'weather', 'today']
# Removed stopwords: ["'s", 'weather', 'today']
# Lemmatization: ["'s", 'weather', 'today']
# ==================================================
# After Lowercase : tell me weather
# Tokens : ['tell', 'me', 'weather']
# Removed Punctuations: ['tell', 'me', 'weather']
# Removed stopwords: ['tell', 'weather']
# Lemmatization: ['tell', 'weather']
# ==================================================
# After Lowercase : is it raining
# Tokens : ['is', 'it', 'raining']
# Removed Punctuations: ['is', 'it', 'raining']
# Removed stopwords: ['raining']
# Lemmatization: ['rain']
# ==================================================
# After Lowercase : open
# Tokens : ['open']
# Removed Punctuations: ['open']
# Removed stopwords: ['open']
# Lemmatization: ['open']
# ==================================================
# After Lowercase : open google
# Tokens : ['open', 'google']
# Removed Punctuations: ['open', 'google']
# Removed stopwords: ['open', 'google']
# Lemmatization: ['open', 'google']
# ==================================================
# After Lowercase : open youtube
# Tokens : ['open', 'youtube']
# Removed Punctuations: ['open', 'youtube']
# Removed stopwords: ['open', 'youtube']
# Lemmatization: ['open', 'youtube']
# ==================================================
# After Lowercase : bye
# Tokens : ['bye']
# Removed Punctuations: ['bye']
# Removed stopwords: ['bye']
# Lemmatization: ['bye']
# ==================================================
# After Lowercase : goodbye
# Tokens : ['goodbye']
# Removed Punctuations: ['goodbye']
# Removed stopwords: ['goodbye']
# Lemmatization: ['goodbye']
# ==================================================

# %%
#clean data
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(clean_data)

# %%
logistic = LogisticRegression()
logistic.fit(X,labels)
# Out:
# LogisticRegression()

# %%
user_input = "hello there"
processed = preprocess_text([user_input])
user_vector = vectorizer.transform(processed)
prediction = logistic.predict(user_vector)
print(prediction)
# Out:
# After Lowercase : hello there
# Tokens : ['hello', 'there']
# Removed Punctuations: ['hello', 'there']
# Removed stopwords: ['hello']
# Lemmatization: ['hello']
# ==================================================
# ['greet']
